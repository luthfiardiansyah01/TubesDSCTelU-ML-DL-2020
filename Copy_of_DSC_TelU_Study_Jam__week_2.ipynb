# %% [markdown]
# ![mlwh.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**OUR TOOLS**

# %% [markdown]
# ##**1. Google Colab**

# %% [markdown]
# <img src="https://miro.medium.com/proxy/0*6ElaVC0Cf4OndZKi.png">

# %% [markdown]
# <img src="https://blogs.bmc.com/wp-content/uploads/2017/09/saas-vs-paas-vs-iaas-1024x953.png" width="50%">

# %% [markdown]
# goole colab, merupakan layanan cloud berbasis **SaaS** / Software as Service yang dapat digunakan oleh semua pengguna akun google untuk menjalankan program berbahasa Python / R secara online dengan format berbasis jupyter notebook sehingga membantu proses prototyping program, beberapa kelebihan google colab:
# <ol type="a">
# <li>Free to use *ada versi premium untuk region US</li>
# <li>Dapat terhubung dengan google drive secara seamless</li>
# <li>Dapat melakukan kode secara kolaboratif</li>
# <li>Terdapat layanan penggunana GPU & TPU gratis</li>
# <li>Cocok untuk anda yang memiliki perangkat berspesifikasi rendah</li>
# </ol>

# %% [markdown]
# ##**2. Python**

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png" width="25%">
# <img src="https://gvanrossum.github.io/images/guido-headshot-2019.jpg" width="25%">

# %% [markdown]
# Python merupakan bahasa pemrograman tingkat tinggi berbasis interpreter yang dinamis dan diciptakan oleh **Guido Van Rossum** pada tahun 1980 an yang terinspirasi dari bahasa pemrograman ABC, python memiliki penulisan gaya penulisan yang indah dan mudah dibaca serta memiliki aturan penulisan yang tertuang pada [PEP-8](https://www.python.org/dev/peps/pep-0008/)

# %% [markdown]
# ##**3. Pandas**

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png" width="50%">

# %% [markdown]
# Pandas (Python Data Analysis Library)merupakan open source library berbasis  python yang biasa digunakan untuk mengubah, mengelola dan melakukan analisis data<br>pandas sendiri dapat membaca hampir seluruh jenis file data yang ada seperti:
# <ol>
# <li>csv</li>
# <li>txt</li>
# <li>sql</li>
# <li>json</li>
# <li>dan masih banyak lagi</li>
# </ol>
#
# bahkan, kita dapat membuat pandas untuk membaca data dari struktur data seperti list & dictionary, hal ini membuat pandas menjadi tools favorit untuk melakukan analisis<br>

# %%
#import pandas dan lakukan inisialisasi dengan nama pd
import pandas as pd

# %% [markdown]
# ##**4. Matplotlib**

# %% [markdown]
# <img src="https://matplotlib.org/_static/logo2_compressed.svg">

# %% [markdown]
# matplotlib merupakan salah satu library pada bahasa pemrograman python yang memiliki fungsi untuk visualisasi data, matplotlib dibuat oleh **John Hunter** pada tahun 2003 sebagai alternatif open source dari matlab yang berbayar

# %%
#import paket pyplot pada matplotlib dan inisialisasi dengan nama plt
from matplotlib import pyplot as plt

# %% [markdown]
# ##**5. Seaborn**

# %% [markdown]
# <img src="https://seaborn.pydata.org/_static/logo-wide-lightbg.svg">

# %% [markdown]
# seaborn merupakan library visualisasi berbasis bahasa pemrograman python pengembangan dari matplotlib, dengan seaborn kita dapat membuat visualisasi setara matplotlib dengan lebih cepat

# %%
#import seaborn dan inisialisasi dengan nama sns
import seaborn as sns
sns.set()

# %% [markdown]
# ##**6. Scikit-learn**

# %% [markdown]
# <img src="https://scikit-learn.org/stable/_static/ml_map.png">

# %% [markdown]
# scikit learn merupakan library berbasis bahasa pemrogram python yang dibuat dengan bantuan library numpy, scipy dan matplotlib
#
# scikit learn menawarkan pembuatan model machine learning dengan cepat dan efisien sehingga user hanya perlu fokus pada pengolahan data
#
# selain terdapat algoritma machine learning didalamnya, scikit learn juga memiliki beberapa tools lain dalam membantu user membangun model machine learning yang baik

# %%
#import paket Logistic Regression pada scikit learn
from sklearn.linear_model import LogisticRegression

#import paket train test split pada scikit learn
from sklearn.model_selection import train_test_split

#import paket classification report pada scikit learn
from sklearn.metrics import classification_report

# %% [markdown]
# ##**7. Pickle**

# %% [markdown]
# <img src="https://www.smartfile.com/blog/wp-content/uploads/2015/11/python-pickle-800x200.png">

# %% [markdown]
# pickle merupakan library berbasis bahasa pemrograman python yang digunakan untuk menyimpan hasil proses pada python ke dalam file yang nanti dapat digunakan lagi dikemudian hari
#
# pickle akan kita gunakan untuk menyimpan model machine learning kita, agar disaat kita ingin menggunakan model kembali, kita tidak perlu melakukan training model kembali

# %%
#melakukan import pickle
import pickle

# %% [markdown]
# #**DATA SCIENCE METHODOLOGY** by IBM

# %% [markdown]
# <img src="https://www.ibmbigdatahub.com/sites/default/files/figure01_revised.jpg" width="80%">

# %% [markdown]
# ##**1. Business Understanding**

# %% [markdown]
# <img src="https://cmusr.files.wordpress.com/2016/01/understanding-business.jpg">

# %% [markdown]
# pada tahap ini kita perlu memahami permasalahan yang kita hadapi, apa yang kita coba untuk capai, dan metrik apa yang kita gunakan sebagai definisi dari **sukses**

# %% [markdown]
# contoh:
#
# <ol type="a">
# <li>permasalahan: </li>
# kemacetan lalu lintas menyebabkan banyak waktu dan uang yang terbuang<br><br>
#
# <li>apa yang ingin dicapai: </li>
# bagaimana cara kita mengoptimalisasi durasi lampu lalu lintas berdasarkan data lalu  lintas, pola yang dimiliki, cuaca dan ada tidaknya pejalan kaki?<br><br>
#
# <li>metrik / hasil yang dapat diukur:</li>
# * berkurangnya durasi waktu perjalanan (%)<br>
# * berkurangnya durasi waktu kemacetan lalu lintas (%)<br><br>
#
#
# </ol>

# %% [markdown]
# ##**2. Analytic Approach**

# %% [markdown]
# <img src="https://onix-systems.com/storage/qaTzU3o-Y9NTi8gtQjRGt6Sqr3OT3nIA.jpg">

# %% [markdown]
# setelah kita memahami **business understanding** yang ada, langkah selanjutnya adalah menentukan pendekatan analisa yang akan kita gunakan, terdapat 4 jenis analisis yang dapat kita gunakan, antara lain:
# <ol type="a">
# <li>Analisis deskriptif</li>
# <li>Analisis diagnostik</li>
# <li>Analisis prediktif</li>
# <li>Analisis prescriptive</li>
# </ol>

# %% [markdown]
# contoh:
# <ol type="a">
# <li>Analisis deskriptif:</li>
# dari data yang dimiliki, kita ingin mengetahui mengenai hal / peristiwa yang terjadi berdasarkan data yang ada<br><br>
#
# <li>Analisis diagnostik:</li>
# analisis yang digunakan untuk menjawab penyebab suatu kejadian terjadi berdasarkan data yang ada<br><br>
#
# <li>Analisis prediktif:</li>
# analisis yang digunakan untuk memprediksi kejadian di masa depan berdasarkan data yang ada
# <br><br>
#
# <li>Analisis prescriptive:</li>
# analisis yang digunakan untuk menghindari permasalahan yang mungkin akan terjadi di masa depan
# <br><br>
# </ol>

# %% [markdown]
# ##**3. Data Requirements**

# %% [markdown]
# <img src="https://miro.medium.com/max/8332/1*wK8k8Vo8_c6jdYIjUWL_Pw.png">

# %% [markdown]
# berdasarkan business problem dan analisis yang kita gunakan, kita perlu menentukan data seperti apa yang tepat untuk menyelesaikan permasalahan kita sehingga goals yang kita inginkan dapat tercapai

# %% [markdown]
# ##**4. Data Collection**

# %% [markdown]
# <img src="https://miro.medium.com/fit/c/1838/551/1*MTWLp_V79poGSZ9W1bHGZA.png">

# %% [markdown]
# setelah kita menetukan data-data yang kita perlukan untuk menyelesaikan permasalahan yang ada, kita masuk ke tahap data collection dimana pada tahap ini kita akan mengumpulkan data -data yang diperlukan, ada beberapa cara yang dapat kita gunakan pada tahapan ini, antara lain:
#
# <ol>
# <li>Mendownload data dari berbagai sumber</li>
# <li>Scraping data</li>
# <li>Pengumpulan data secara manual</li>
# <li>Dkk</li>
# </o>

# %%
#melakukan download terhadap data yang kita inginkan
sourceData = 'https://raw.githubusercontent.com/TynClause/dataset_DSC/main/kc_house_data.csv'

#melakukan load data kedalam pandas dataframe
df = pd.read_csv(sourceData)

#mengeluarkan 5 nilai teratas pada data
df.head()
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3  2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4  1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ###**contoh**

# %%
#melakukan download terhadap data yang kita inginkan
sourceData = 'https://raw.githubusercontent.com/TynClause/dataset_DSC/main/kc_house_data.csv'

#melakukan load data kedalam pandas dataframe
df = pd.read_csv(sourceData)

#mengeluarkan 5 nilai teratas pada data
df.head()

# %% [markdown]
# ##**5. Data Understanding / Exploratory Data Analysis (EDA)**

# %% [markdown]
# <img src="https://miro.medium.com/max/1130/1*3sr-fMg4S_yEncGsIjyG9A.png">

# %% [markdown]
# Exploratory Data Analysis (EDA) merupakan tahapan paling penting dalam pembuatan model machine learning, mayoritas waktu yang digunakan seseorang dalam melakukan EDA biasanya lebih banyak ketimbang di pembuatan model dikarenakan saat ini banyak library-library yang telah tersedia untuk mempercepat pembuatan model machine learning<br><br>
#
# pada tahap ini, kita melakukan pengecekan karakteristik dari data yang kita miliki bisa dengan melihat statistik data yang ada, melihat mean, median, range, frekuensi dan masih banyak lagi agar kita lebih memahami data yang kita miliki itu seperti apa<br><br>
#
# pada tahap ini pula biasanya kita melakukan visualisasi pada feature agar memudahkan kita dalam mempelajari karakteristik data yang kita miliki<br><br>
#
# apabila kalian, tertarik untuk mempelajari EDA, kalian bisa membuka [link ini](https://medium.com/data-folks-indonesia/memahami-data-dengan-exploratory-data-analysis-a53b230cce84) untuk mengenali EDA lebih lanjut atau, kalian bisa membeli buku dari [John Tukey: Exploratory Data Analysis](https://www.amazon.com/Exploratory-Data-Analysis-John-Tukey/dp/0201076160)

# %% [markdown]
# ###mari kita lihat sekilas info mengenai dataframe yang kita miliki!

# %%
#melihat sekalias info pada dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# ###contoh

# %%
#melihat sekalias info pada dataframe
df.info()

# %% [markdown]
# ###setelah itu, kita lakukan pengecekan pada dataframe yang bersangkutan, apakah terdapat nilai kosong pada dataframe tersebut?

# %%
#lakukan pengecekan apakah ada nilai kosong pada dataframe
df.loc[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %% [markdown]
# ###contoh

# %%
#lakukan pengecekan apakah ada nilai kosong pada dataframe
df.loc[df.isnull().any(axis=1)]

# %% [markdown]
# ###mari kita lihat statistik deskriptif yang terdapat pada dataframe kita!

# %%
#melihat statistik deskriptif dari dataframe
df.describe(include='all').T
# Out:
#                count unique        top  ...          50%         75%          max
# id             21597    NaN        NaN  ...  3.90493e+09  7.3089e+09      9.9e+09
# date           21597    372  6/23/2014  ...          NaN         NaN          NaN
# price          21597    NaN        NaN  ...       450000      645000      7.7e+06
# bedrooms       21597    NaN        NaN  ...            3           4           33
# bathrooms      21597    NaN        NaN  ...         2.25         2.5            8
# sqft_living    21597    NaN        NaN  ...         1910        2550        13540
# sqft_lot       21597    NaN        NaN  ...         7618       10685  1.65136e+06
# floors         21597    NaN        NaN  ...          1.5           2          3.5
# waterfront     21597    NaN        NaN  ...            0           0            1
# view           21597    NaN        NaN  ...            0           0            4
# ...

# %% [markdown]
# ###contoh

# %%
#melihat statistik deskriptif dari dataframe
df.describe(include='all').T

# %% [markdown]
# ###dari data diatas, mari kita lihat sebaran dataharga rumah dengan menggunakan bantuan visualisasi seaborn!

# %%
#melihat sebaran data harga rumah dengan visualisasi seaborn
sns.set()
sns.distplot(df['price'])
plt.title('SEBARAN DATA HARGA RUMAH', fontweight='bold')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###contoh

# %%
#melihat sebaran data harga rumah dengan visualisasi seaborn
plt.style.use('seaborn')
plt.figure(figsize=(10,5))
sns.distplot(df['price'])
plt.title('MELIHAT SEBARAN HARGA RUMAH', fontweight='bold')
plt.show()

# %% [markdown]
# ###sepertinya, kita perlu melihat data bedrooms tiap rumah yang terdapat pada dataset kita

# %%
#lihat data bedrooms pada rumah
sns.countplot(df['bedrooms'])
plt.title('JUMLAH TEMPAT TIDUR', fontweight='bold')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###contoh

# %%
#lihat data bedrooms pada rumah
plt.style.use('seaborn')
plt.figure(figsize=(10,5))
sns.countplot(df['bedrooms'])
plt.title('BANYAK KAMAR PADA RUMAH', fontweight='bold')
plt.show()

# %% [markdown]
# ###selanjutnya, mari kita lihat hubungan antara harga rumah dan ukuran dari ruang tamu yang dimiliki tiap rumah!

# %%
#lihat hubungan antara harga rumah dan ukuran ruang tamu
sns.scatterplot(x=df['price'], y=df['sqft_living'])
plt.title('HUBUNGAN ANTARA HARGA DAN UKURAN RUANG TAMU', fontweight='bold')
plt.show()

# %% [markdown]
# ###contoh

# %%
#lihat hubungan antara harga rumah dan ukuran ruang tamu
plt.style.use('seaborn')
plt.figure(figsize=(10,5))
sns.scatterplot(x=df['price'], y=df['sqft_living'])
plt.title('HUBUNGAN HARGA RUMAH DAN UKURAN RUANG TAMU', fontweight='bold')
plt.show()

# %% [markdown]
# ###mari kita lihat hubungan antara jumlah kamar dengan harga rumah yang ada

# %%
#lihat hubungan antara jumlah kamar dengan harga
sns.scatterplot(x=df['bedrooms'], y=df['price'])
plt.title('HUBUNGAN ANTARA JUMLAH KAMAR DENGAN HARGA RUMAH', fontweight='bold')
plt.show()

# %% [markdown]
# ###contoh

# %%
#lihat hubungan antara jumlah kamar dengan harga
plt.style.use('seaborn')
plt.figure(figsize=(10,5))
sns.boxplot(x=df['bedrooms'], y=df['price'])
plt.title('HUBUNGAN KAMAR DENGAN HARGA', fontweight='bold')
plt.show()

# %% [markdown]
# ###mari kita sort nilai berdasarkan harga terbesar & tampilkan 10 nilai teratas pada data kita

# %%
#sort data berdasarkan harga terbesar & tampilkan 10 nilai teratas
newDF = df.sort_values('price', ascending=False)
newDF.head()
# Out:
#               id        date      price  ...     long  sqft_living15  sqft_lot15
# 7245  6762700020  10/13/2014  7700000.0  ... -122.323           3940        8800
# 3910  9808700762   6/11/2014  7060000.0  ... -122.214           3930       25449
# 9245  9208900037   9/19/2014  6890000.0  ... -122.240           4540       42730
# 4407  2470100110    8/4/2014  5570000.0  ... -122.233           3560       24345
# 1446  8907500070   4/13/2015  5350000.0  ... -122.220           4600       21750
#
# [5 rows x 21 columns]

# %% [markdown]
# ###contoh

# %%
#sort data berdasarkan harga terbesar & tampilkan 10 nilai teratas
df.sort_values('price', ascending=False).head(10)

# %% [markdown]
# ###ambil daftar rumah top 1% berdasarkan harga tertinggi saja!

# %%
#ambil data top 1% rumah berdasarkan harga saja
persentase = int(len(newDF) * 0.01)
topDF = df.iloc[:persentase]
topDF.shape
# Out:
# (215, 21)

# %% [markdown]
# ###contoh

# %%
#ambil data top 1% rumah berdasarkan harga saja
persentase = len(df)*0.01
topRumah  = df.sort_values('price', ascending=False).reset_index()
topRumah  = topRumah.iloc[:int(persentase)]

# %% [markdown]
# ###diakhir, kita coba visualisasikan data berdasarkan rumah top 1% dan harga rumah regular

# %%
#visualisasi posisi rumah top 1%
sns.scatterplot('long', 'lat', data=topDF, color='green', label='REGULAR', alpha=0.2)
sns.scatterplot('long', 'lat', data=topDF, color='red', label='TOP 1%', alpha=0.5)
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ###contoh

# %%
#visualisasi posisi rumah top 1%
plt.style.use('seaborn')
plt.figure(figsize=(10,5))
sns.scatterplot(x='long', y='lat', color='green', alpha=0.1, data=df, label='Rumah regular')
sns.scatterplot(x='long', y='lat', color='red', alpha=0.5, data=topRumah, label='Rumah Top 1%')
plt.title('POSISI TOP 1% RUMAH DI BOSTON', fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# ##**6. Data Preparation / Preprocessing Data**

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/fit/t/1600/480/1*R4-4bJHAC6hWVj62u1tbzA.jpeg">

# %% [markdown]
# setelah kita memahami kondisi data yang kita miliki, kita dapat mengetahui hal apa saja yang kita harus lakukan agar data yang kita miliki siap untuk di masukkan kedalam model machine learning, beberapa hal yang biasanya dapat dilakukan ialah:
# <ul>
# <li>membuang nilai kosong</li>
# <li>membuang nilai duplikat</li>
# <li>melakukan imputasi nilai</li>
# <li>standarisasi satuan data</li>
# <li>menggabungkan beberapa data menjadi satu</li>
# <li>feature engineering</li>
# <li>transformasi data</li>
# <li>dkk</li>
# </ul>

# %% [markdown]
# ### mari kita cek terlebih dahulu tipe data tiap feature

# %%
#tampilkan informasi tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# ### contoh

# %%
#tampilkan informasi tipe data
df.info()

# %% [markdown]
# ### buang feature id di dataframe kita

# %%
#buang feature id karena bersifat unique dan tidak memiliki keterkaitan dengan harga
df.drop('id', axis=1, inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-a5b8427c562b> in <module>()
#       1 #buang feature id karena bersifat unique dan tidak memiliki keterkaitan dengan harga
# ----> 2 df.drop('id', axis=1, inplace=True)
#       3 df.head()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %% [markdown]
# ### contoh

# %%
#buang feature id karena bersifat unique dan tidak memiliki keterkaitan dengan harga
df = df.drop('id',axis=1)

# %% [markdown]
# ### peroleh bulan dan tahun dari feature date

# %%
#peroleh data bulan dan tahun dari feature date
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].apply(lambda date:date.month)
df['year'] = df['date'].apply(lambda date:date.year)
df.head()
# Out:
#         date     price  bedrooms  ...  sqft_lot15  month  year
# 0 2014-10-13  221900.0         3  ...        5650     10  2014
# 1 2014-12-09  538000.0         3  ...        7639     12  2014
# 2 2015-02-25  180000.0         2  ...        8062      2  2015
# 3 2014-12-09  604000.0         4  ...        5000     12  2014
# 4 2015-02-18  510000.0         3  ...        7503      2  2015
#
# [5 rows x 22 columns]

# %% [markdown]
# ### contoh

# %%
#peroleh data bulan dan tahun dari feature date
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].apply(lambda date:date.month)
df['year'] = df['date'].apply(lambda date:date.year)

# %% [markdown]
# ### peroleh insight dari feature tahun dengan harga dengan menggunakan boxplot

# %%
#tampilkan visualisasi terhadap feature tahun dan harga dengan boxplot
sns.boxplot(x='year', y='price', data=df)
plt.title('RELASI ANTARA TAHUN DENGAN HARGA', fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'RELASI ANTARA TAHUN DENGAN HARGA')

# %% [markdown]
# ### contoh

# %%
#tampilkan tahun x harga dengan boxplot
sns.boxplot(x='year',y='price',data=df)

# %% [markdown]
# ### peroleh insight dari feature bulan dengan harga dengan menggunakan boxplot

# %%
#tampilkan visualisasi terhadap feature bulan dan harga dengan boxplot
sns.boxplot(x='month',y='price',data=df)

# %% [markdown]
# ### contoh

# %%
#tampilkan visualisasi terhadap feature bulan dan harga dengan boxplot
sns.boxplot(x='month',y='price',data=df)

# %% [markdown]
# ### peroleh insight rata-rata penjualan tiap bulan menggunakan lineplot

# %%
#visualisasikan rata-rata harga per bulan menggunakan lineplot
df.groupby('month').mean()['price'].plot()

# %% [markdown]
# ### contoh

# %%
#visualisasikan rata-rata harga per bulan menggunakan lineplot
df.groupby('month').mean()['price'].plot()

# %% [markdown]
# ### peroleh insight rata-rata penjualan tiap tahun menggunakan lineplot

# %%
#lakukan hal sama tapi untuk tahun
df.groupby('year').mean()['price'].plot()

# %% [markdown]
# ### contoh

# %%
#lakukan hal sama tapi untuk tahun
df.groupby('year').mean()['price'].plot()

# %% [markdown]
# ### buang feature date

# %%
#buang date karena sudah di feature engineering
df = df.drop('date',axis=1)

# %% [markdown]
# ### contoh

# %%
#buang date karena sudah di feature engineering
df = df.drop('date',axis=1)

# %% [markdown]
# ### cek feature zipcode apakah bisa digunakan sebagai feature

# %%
#lihat jumlah unique value di feature zipcode
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %% [markdown]
# ### contoh

# %%
#lihat jumlah unique value di feature zipcode
df['zipcode'].value_counts()

# %% [markdown]
# ### buang feature zipcode

# %%
#buang feature zipcode
df = df.drop('zipcode',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-a8a6c37f47c5> in <module>()
#       1 #buang feature zipcode
# ----> 2 df = df.drop('zipcode',axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %% [markdown]
# ### contoh

# %%
#buang feature zipcode
df = df.drop('zipcode',axis=1)

# %% [markdown]
# ### cek feature tahun renovasi apakah bisa digunakan sebagai feature

# %%
#lihat jumlah unique value di feature yr_renovated
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %% [markdown]
# ### contoh

# %%
#lihat jumlah unique value di feature yr_renovated
df['yr_renovated'].value_counts()

# %% [markdown]
# ### cek feature luas basement apakah bisa digunakan sebagai feature

# %%
#lihat jumlah unique value di feature sqft_basement
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %% [markdown]
# ### contoh

# %%
#lihat jumlah unique value di feature sqft_basement
df['sqft_basement'].value_counts()

# %% [markdown]
# ### pisah feature X dan y

# %%
#tentukan mana yang variabel depending (y) dan variabel independent (x)
X = df.drop('price',axis=1)
y = df['price']

# %% [markdown]
# ### contoh

# %%
#tentukan mana yang variabel depending (y) dan variabel independent (x)
X = df.drop('price',axis=1)
y = df['price']

# %% [markdown]
# ### Bagi data train dan test menggunakan train_test_split

# %%
#split data jadi train dan test dengan train_test_split, data test sebesai 30% dengan random state 101
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %% [markdown]
# ### contoh

# %%
#split data jadi train dan test dengan train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %% [markdown]
# ### Cek jumlah data train dan test

# %%
#cek jumlah data
X_train_shape = X_train.shape
X_test_shape = X_test.shape
y_train_shape = y_train.shape
y_test_shape = y_test.shape
print(f'shape tiap data\nX_train :{X_train_shape}\n X_test :{X_test_shape}\ny_train :{y_train_shape}\ny_test :{y_test_shape}')
# Out:
# shape tiap data
# X_train :(15117, 19)
#  X_test :(6480, 19)
# y_train :(15117,)
# y_test :(6480,)

# %% [markdown]
# ### contoh

# %%
#cek jumlah data
X_train_shape = X_train.shape
X_test_shape = X_test.shape
y_train_shape = y_train.shape
y_test_shape = y_test.shape
print(f'shape tiap data\nX_train :{X_train_shape}\n X_test :{X_test_shape}\ny_train :{y_train_shape}\ny_test :{y_test_shape}')

# %% [markdown]
# ### inisialisasi StandardScaler

# %%
#normalisasi dengan StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# ### contoh

# %%
#normalisasi dengan StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %% [markdown]
# ### Normalisasi feature menggunakan standard scaller

# %%
#transform dengan scaller
X_train= scaler.fit_transform(X_train)
#scaller ke x_test
X_test = scaler.transform(X_test)

# %% [markdown]
# ### contoh

# %%
#transform
X_train= scaler.fit_transform(X_train)
#scaller ke x_test
X_test = scaler.transform(X_test)

# %% [markdown]
# ##**7. Modeling**

# %% [markdown]
# <img src="https://cdn.educba.com/academy/wp-content/uploads/2019/09/Machine-Learning-Models.png">

# %% [markdown]
# setelah data yang kita miliki telah siap digunakan untuk dimasukkan kedalam model agar model dapat belajar menggunakan data yang ada, langkah selanjutnya adalah memilih algoritma machine learning yang akan kita gunakan berdasarkan karakteristik dari data yang kita miliki!
# <br><br>
# apabila kalian tertarik untuk mengetahui kelebihan dan kekurangan dari model machine learning yang ada, kalian dapat melihatnya [disini](https://towardsdatascience.com/comparative-study-on-classic-machine-learning-algorithms-24f9ff6ab222) & [disini](https://towardsdatascience.com/comparative-study-on-classic-machine-learning-algorithms-24f9ff6ab222)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### buat objek model terlebih dahulu

# %%
#buat objek model ElasticNet
lr = LinearRegression()
#buat objek Decision Tree
dt = DecisionTreeRegressor()
#buat objek Random Forest
rf = RandomForestRegressor()

# %% [markdown]
# ### contoh

# %%
# en = ElasticNet(alpha=0.8,l1_ratio=1,selection='random',tol=0.001,warm_start=True,max_iter=100)
lr = LinearRegression()
dt = DecisionTreeRegressor()
rf = RandomForestRegressor()

# %% [markdown]
# ### Training model dengan data yang sudah ada

# %%
#training model dengan data yang sudah ada
lr.fit(X_train,y_train)
dt.fit(X_train,y_train)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# ### contoh

# %%
lr.fit(X_train,y_train)
dt.fit(X_train,y_train)
rf.fit(X_train,y_train)

# %% [markdown]
# ##**8. Evaluation**

# %% [markdown]
# <img src= "https://www.datavedas.com/wp-content/uploads/2018/05/4-MODEL-EVALUATION-AND-VALIDATION-S-1.jpg">

# %% [markdown]
# setelah model machine learning yang kita buat telah selesai, kita perlu melakukan evaluasi terhadap model machine learning yang kita buat<br><br>
#
# biasanya kita dapat melakukan pengecekan performa dari model kita berdasarkan akurasi yang dimiliki dan nilai loss yang ada
#
#
# untuk kasus model regresi, metrik yang populer digunakan adalah:
# <ul>
# <li>R**2</li>
# <li>RMSE</li>
# <li>MAE</li>
# </ul>
#
# apabila kalian tertarik mengenai metrik diatas, kalian bisa mencarinya [disini](https://towardsdatascience.com/what-are-the-best-metrics-to-evaluate-your-regression-model-418ca481755b)

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ### evaluasi menggunakan R2 Score

# %%
#gunakan r2_score untuk melihat akurasinya, r2_score(y_true,y_pred)

r2Score_lr = r2_score(y_test,lr.predict(X_test))
r2Score_dt = r2_score(y_test,dt.predict(X_test))
r2Score_rf = r2_score(y_test,rf.predict(X_test))

print(f"nilai Hasil evaluasi R2 :{round(r2Score_en,2)}")
print(f"nilai Hasil evaluasi R2 :{round(r2Score_dt,2)}")
print(f"nilai Hasil evaluasi R2 :{round(r2Score_rf,2)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-ab541cc76ff7> in <module>()
#       5 r2Score_rf = r2_score(y_test,rf.predict(X_test))
#       6
# ----> 7 print(f"nilai Hasil evaluasi R2 :{round(r2Score_en,2)}")
#       8 print(f"nilai Hasil evaluasi R2 :{round(r2Score_dt,2)}")
#       9 print(f"nilai Hasil evaluasi R2 :{round(r2Score_rf,2)}")
#
# NameError: name 'r2Score_en' is not defined

# %% [markdown]
# ### contoh

# %%
#gunakan r2_score untuk melihat akurasinya, r2_score(y_true,y_pred)

r2Score_lr = r2_score(y_test,lr.predict(X_test))
r2Score_dt = r2_score(y_test,dt.predict(X_test))
r2Score_rf = r2_score(y_test,rf.predict(X_test))

print(f"nilai Hasil evaluasi R2 :{round(r2Score_lr,2)}")
print(f"nilai Hasil evaluasi R2 :{round(r2Score_dt,2)}")
print(f"nilai Hasil evaluasi R2 :{round(r2Score_rf,2)}")
# Out:
# nilai Hasil evaluasi R2 :0.7
# nilai Hasil evaluasi R2 :0.74
# nilai Hasil evaluasi R2 :0.88

# %%
#cek feature yang paling penting dari prediksi
rf.feature_importances_
# Out:
# array([0.00289197, 0.00712889, 0.25848253, 0.01305178, 0.00182103,
#        0.03849437, 0.01204775, 0.00271962, 0.31109937, 0.02527218,
#        0.00510395, 0.02884307, 0.00195582, 0.1637317 , 0.0737036 ,
#        0.0335619 , 0.01310535, 0.00578651, 0.00119862])

# %%
def prediksi(nama_data):
  sourceData = nama_data
  x = pd.read_csv(sourceData)
  x = df.drop('id',axis=1)
  x['date'] = pd.to_datetime(x['date'])
  x['month'] = x['date'].apply(lambda date:date.month)
  x['year'] = x['date'].apply(lambda date:date.year)
  x = x.drop('date',axis=1)
  x = scaler.transform(x)
  y_pred = rf.predict(x)
  return scaler.reverse_transform(y_pred)

# %%
prediksi(https://raw.githubusercontent.com/TynClause/dataset_DSC/main/data_baru.csv)

# %% [markdown]
# ##**9. Deployment**

# %% [markdown]
# <img src="https://cdn.lynda.com/course/421800/421800-637286180187241484-16x9.jpg">

# %% [markdown]
# setelah performa model machine learning dirasa cukup, kita bisa melakukan proses deployment terhadap model yang kita miliki<br><br>
#
# untuk model machine learning klasik, kita dapat melakukan deploy dengan bantuan module pickle, sedangkan untuk model deep learning, pada umumnya telah menyediakan metode penyimpanan model yang telah dibuat

# %%
#simpan model
filename = 'model_prediksi_harga.pkl'

# %% [markdown]
# ### contoh

# %%
#simpan model
filename = 'model_prediksi_harga.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %%
#pakai model

# %% [markdown]
# ##**10. Feedback**

# %% [markdown]
# <img src="https://liquidplanner-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/done-sticky-note.jpg">

# %% [markdown]
# Pada langkah ini, kita akan meminta feedback dari pihak bersangkutan untuk memberikan masukan mengenai produk yang telah kita bangun, apabila dari pihak tersebut merasa bahwa produk kita sudah baik, maka projek yang telah kita bangun dapat dianggap "Selesai"<br><br>
#
# namun, apabila masih ada yang perlu ditambahkan, kita perlu untuk memperbaiki hal yang kurang hingga mencapai kriteria yang diinginkan!
